# %%
#https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.subplot.html
#https://numpy.org/doc/stable/reference/generated/numpy.linspace.html
#https://stackoverflow.com/questions/3584805/what-does-the-argument-mean-in-fig-add-subplot111

# %%
import matplotlib.pyplot as plt 
names = ['group_a', 'group_b', 'group_c']
values = [1, 10, 100]

plt.figure(figsize=(9, 3))

plt.subplot(131) #plt.subplot(1,3,1)
plt.bar(names, values)
plt.subplot(132)
plt.scatter(names, values)
plt.subplot(133)
plt.plot(names, values)
plt.suptitle('Categorical Plotting')
plt.show()

# %%
import matplotlib.pyplot as plt 

x=[1,2,3,4,5,6]
y=[4,3,5,6,7,4]

fig=plt.figure()

subplot1=fig.add_subplot(2,1,1)
subplot1.plot(x, y)

subplot2=fig.add_subplot(2,1,2)
subplot2.text(0.3, 0.5, '2nd Subplot')

fig.suptitle("Add subplots to a figure")
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt



def f(t):
    return np.exp(-t) * np.cos(2*np.pi*t)


t1 = np.arange(0.0, 3.0, 0.01)

ax1 = plt.subplot(212)
ax1.margins(0.05)           # Default margin is 0.05, value 0 means fit
ax1.plot(t1, f(t1))

ax2 = plt.subplot(221)
ax2.margins(2, 2)           # Values >0.0 zoom out
ax2.plot(t1, f(t1))
ax2.set_title('Zoomed out')

ax3 = plt.subplot(222)
ax3.margins(x=0, y=-0.25)   # Values in (-0.5, 0.0) zooms in to center
ax3.plot(t1, f(t1))
ax3.set_title('Zoomed in')

plt.show()

# %%
import numpy as np 
import matplotlib.pyplot as plt 
  
   
x = np.linspace(0, 10, 500) 
y = np.sin(x**2)+np.cos(x) 
   
fig, ax = plt.subplots() 
   
ax.plot(x, y, label ='Line 1') 
   
ax.plot(x, y - 0.6, label ='Line 2') 
   
ax.legend() 
  
fig.suptitle("graph", fontweight ="bold")  
  
#fig.show()
# Out:
# Text(0.5, 0.98, 'graph')

# %%
import matplotlib.pyplot as plt
fig = plt.figure()
fig.add_subplot(221)   #top left
fig.add_subplot(222)   #top right
fig.add_subplot(223)   #bottom left
fig.add_subplot(224)   #bottom right 
plt.show()

# %%
import matplotlib.pyplot as plt
fig = plt.figure()
fig.add_subplot(211)   #top left
#fig.add_subplot(222)   #top right
fig.add_subplot(223)   #bottom left
fig.add_subplot(224)   #bottom right 
plt.show()

# %%
import matplotlib.pyplot as plt 
fig, axs = plt.subplots(2, 2)
axs[0, 0].plot(x, y)
axs[0, 0].set_title('Axis [0, 0]')
axs[0, 1].plot(x, y, 'tab:orange')
axs[0, 1].set_title('Axis [0, 1]')
axs[1, 0].plot(x, -y, 'tab:green')
axs[1, 0].set_title('Axis [1, 0]')
axs[1, 1].plot(x, -y, 'tab:red')
axs[1, 1].set_title('Axis [1, 1]')

for ax in axs.flat:
    ax.set(xlabel='x-label', ylabel='y-label')

# Hide x labels and tick labels for top plots and y ticks for right plots.
for ax in axs.flat:
    ax.label_outer()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [41], in <cell line: 7>()
#       5 axs[0, 1].plot(x, y, 'tab:orange')
#       6 axs[0, 1].set_title('Axis [0, 1]')
# ----> 7 axs[1, 0].plot(x, -y, 'tab:green')
#       8 axs[1, 0].set_title('Axis [1, 0]')
#       9 axs[1, 1].plot(x, -y, 'tab:red')
#
# TypeError: bad operand type for unary -: 'list'

# %%
#quiz 3-4 
#03-04

def calc_digit(n): 
    def final(digit): 
        print("digit vale:",digit**n)
        return digit**n 
    print("final vale:",final)  
    return final 
num_list=[] 
for num in range(1,6): 
    print("num vale:",num)
    num_list.append(calc_digit(num)) 
    print("final en el for es :",num_list[num-1] )
    
    print(num_list[num-1](num)) # es lo mismo que print(final(num)) # proceso= function calc_digit.<locals>.final at 0x000001E8395028B0(num)
    
    
print("_________________-")
print(num_list)
# Out:
# num vale: 1
# final vale: <function calc_digit.<locals>.final at 0x000001E839514790>
# final en el for es : <function calc_digit.<locals>.final at 0x000001E839514790>
# digit vale: 1
# 1
# num vale: 2
# final vale: <function calc_digit.<locals>.final at 0x000001E83AD61280>
# final en el for es : <function calc_digit.<locals>.final at 0x000001E83AD61280>
# digit vale: 4
# 4
# num vale: 3
# final vale: <function calc_digit.<locals>.final at 0x000001E839511430>
# final en el for es : <function calc_digit.<locals>.final at 0x000001E839511430>
# digit vale: 27
# 27
# num vale: 4
# final vale: <function calc_digit.<locals>.final at 0x000001E8395118B0>
# final en el for es : <function calc_digit.<locals>.final at 0x000001E8395118B0>
# digit vale: 256
# 256
# num vale: 5
# final vale: <function calc_digit.<locals>.final at 0x000001E839511C10>
# final en el for es : <function calc_digit.<locals>.final at 0x000001E839511C10>
# digit vale: 3125
# 3125
# _________________-
# [<function calc_digit.<locals>.final at 0x000001E839514790>, <function calc_digit.<locals>.final at 0x000001E83AD61280>, <function calc_digit.<locals>.final at 0x000001E839511430>, <function calc_digit.<locals>.final at 0x000001E8395118B0>, <function calc_digit.<locals>.final at 0x000001E839511C10>]

# %% [markdown]
# # Ejercicios
# -------------------
#
# El fin de estos ejercicios es que vayan tomando agilidad en como pensar con Python y como resolver problemas que les puedan aparecer en la via.

# %% [markdown]
# ### Ejercicio 1.a
# * Usa la libreria <code>math</code> para calcular e imprimir el valor de $\frac{\pi}{4}$

# %%
#tu codigo

# %% [markdown]
# ### Ejercicio 1.b
# * Usa la libreria <code>random</code> y usando <code>random.uniform()</code>
#
# * Crea una funcion llamada <code>rand()</code> que genere un numero entre -1 y 1

# %%
random.seed(1) # Deja esto en tu codigo para todos tener el mismo resultado

#tu codigo

# %% [markdown]
# ## Ejercicio 1.c
# ![image.png](attachment:95394aea-80b6-475b-b9e4-8bde5e955c3e.png)
#
# La distancia entre dos puntos **<code>X</code>** y **<code>Y</code>** es igual a la raiz de la suma de la diferencia de sus cuadrados
#
# * crea una funcion llamada <code> distancia(x,y)</code> que tome estos dos vectores **<code>X=(0,0)</code>** y **<code>Y=(1,1)</code>** como entrada y de salida nos devuelva el resultado de esta operacion matematica
#
#     Usar libreria <code>math</code>

# %%
def distancia(x,y):
    #tu codigo

# %% [markdown]
# ### Ejercicio 1.d
#
# * Escribe una funcion <code>dentro_circulo(x,origen)</code> que determine si un punto de dos dimensiones <code>x=(1,1)</code> esta dentro de un circulo de una unidad de radio
#
#     * Tu funcion deberia devolver un booleano <code> True </code> si la distancia entre **x** y **el origen** es menor a **1** y devolver Falso si es de otra manera.
#     * usa la funcion <code>distancia(x,y)</code> definida en el ejercicio 2.c
#
# * Usa tu nueva funcion <code>dentro_circulo(x,origen)</code> para determinar si el punto <code>x=(1,1)</code> esta dentro del circulo centrado en(0,0)

# %%
def dentro_circulo(x,origen=[0,0]):
    #tu codigo

# %% [markdown]
# ### Ejercicio 1.e
# - Crea una lista llamada 'dentro' de R=10000 booleanos que determinen.
#     - Usa la funcion <code> rand()</code> del ejercicio **2.b** para generar **R** puntos localizados de manera aleatoria.
#     - Use la funcion <code>dentro_circulo()</code> para probar si un punto esta dentro del circulo.
# - Obten una proporcion de los puntos que caen dentro del circulo sumando todos los valores`True` dentro de la lista `dentro` ;luego divide la respuesta entre `R` para obtener una proporcion.
# - Imprime tu respuesta.

# %%
import math, random
random.seed(1)
puntos=[]
dentro=[]
fuera=[]

# %%
#Desenpacar Tuplas
x,y=(2,5)
print(x)
print(y)
# Out:
# 2
# 5
